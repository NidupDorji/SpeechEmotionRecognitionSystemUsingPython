# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('TESS_Toronto_emotional_speech_set_data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['TESS_Toronto_emotional_speech_set_data/YAF_disgust/YAF_date_disgust.wav',
#  'TESS_Toronto_emotional_speech_set_data/YAF_disgust/YAF_rag_disgust.wav',
#  'TESS_Toronto_emotional_speech_set_data/YAF_disgust/YAF_raise_disgust.wav',
#  'TESS_Toronto_emotional_speech_set_data/YAF_disgust/YAF_ditch_disgust.wav',
#  'TESS_Toronto_emotional_speech_set_data/YAF_disgust/YAF_door_disgust.wav']

# %%
labels[:5]
# Out:
# ['disgust', 'disgust', 'disgust', 'disgust', 'disgust']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech    label
# 0  TESS_Toronto_emotional_speech_set_data/YAF_dis...  disgust
# 1  TESS_Toronto_emotional_speech_set_data/YAF_dis...  disgust
# 2  TESS_Toronto_emotional_speech_set_data/YAF_dis...  disgust
# 3  TESS_Toronto_emotional_speech_set_data/YAF_dis...  disgust
# 4  TESS_Toronto_emotional_speech_set_data/YAF_dis...  disgust

# %%
df['label'].value_counts()
# Out:
# label
# disgust    400
# ps         400
# happy      400
# sad        400
# neutral    400
# fear       400
# angry      400
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(df['label'])
# Out:
# <Axes: xlabel='count', ylabel='label'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveplot(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       2 path = np.array(df['speech'][df['label']==emotion])[0]
#       3 data, sampling_rate = librosa.load(path)
# ----> 4 waveplot(data, sampling_rate, emotion)
#       5 spectogram(data, sampling_rate, emotion)
#       6 Audio(path)
#
# Cell In[9], line 4, in waveplot(data, sr, emotion)
#       2 plt.figure(figsize=(10,4))
#       3 plt.title(emotion, size=20)
# ----> 4 librosa.display.waveplot(data, sr=sr)
#       5 plt.show()
#
# AttributeError: module 'librosa.display' has no attribute 'waveplot'

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 path = np.array(df['speech'][df['label']==emotion])[1]
#       3 data, sampling_rate = librosa.load(path)
# ----> 4 waveplot(data, sampling_rate, emotion)
#       5 spectogram(data, sampling_rate, emotion)
#       6 Audio(path)
#
# Cell In[9], line 4, in waveplot(data, sr, emotion)
#       2 plt.figure(figsize=(10,4))
#       3 plt.title(emotion, size=20)
# ----> 4 librosa.display.waveplot(data, sr=sr)
#       5 plt.show()
#
# AttributeError: module 'librosa.display' has no attribute 'waveplot'

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-4.4636795e+02,  7.3789307e+01,  1.5521719e+00,  4.0626896e+01,
#        -8.4494524e+00, -2.9341390e+00, -6.6822028e+00, -1.7199314e+01,
#        -5.6114125e+00, -1.3409514e+01, -7.3893199e+00,  6.8370872e+00,
#        -1.0458900e+01,  3.2033248e+00, -1.0037700e+00, -5.6148534e+00,
#         4.2504106e+00, -1.1169560e+00, -9.1154451e+00,  2.1831045e+00,
#        -7.7419267e+00,  6.4607906e-01, -3.6939952e+00,  3.7297630e-01,
#        -2.0016887e+00, -1.8217636e+00, -2.7837276e+00,  2.8430927e+00,
#        -3.0322783e+00,  4.5028725e+00, -8.8743937e-01,  4.2168193e+00,
#         1.7408412e+00,  3.8251688e+00,  4.3130198e+00,  3.1095667e+00,
#         3.5192683e+00,  4.1317463e+00,  2.2578502e+00,  2.3055403e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-446.36795, 73.78931, 1.552172, 40.626896, -8...
# 1       [-383.37564, 108.15568, -17.578175, 15.888096,...
# 2       [-404.0382, 87.21107, 0.48701975, 22.224413, -...
# 3       [-444.80597, 67.52622, -3.808903, 31.318571, -...
# 4       [-430.42755, 118.75985, 6.9652796, 5.204931, -...
#                               ...
# 2795    [-574.7826, 95.66922, 34.85124, 16.821632, 17....
# 2796    [-557.9271, 89.87658, 33.661488, 15.33976, 22....
# 2797    [-527.0877, 115.282486, 26.17239, 7.6268435, 1...
# 2798    [-560.78094, 121.28371, 40.302486, -1.9568781,...
# 2799    [-552.6838, 106.72334, 35.1727, 8.060721, 22.6...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2023-11-05 20:41:49.101990: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 8s 159ms/step - loss: 1.1975 - accuracy: 0.5406 - val_loss: 1.1879 - val_accuracy: 0.5071
# Epoch 2/50
# 35/35 [==============================] - 5s 155ms/step - loss: 0.3038 - accuracy: 0.8982 - val_loss: 2.1250 - val_accuracy: 0.5804
# Epoch 3/50
# 35/35 [==============================] - 6s 162ms/step - loss: 0.2026 - accuracy: 0.9424 - val_loss: 2.0744 - val_accuracy: 0.4804
# Epoch 4/50
# 35/35 [==============================] - 6s 168ms/step - loss: 0.1503 - accuracy: 0.9576 - val_loss: 1.9202 - val_accuracy: 0.5446
# Epoch 5/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.1188 - accuracy: 0.9643 - val_loss: 1.6326 - val_accuracy: 0.6089
# Epoch 6/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.1313 - accuracy: 0.9625 - val_loss: 2.2245 - val_accuracy: 0.5768
# Epoch 7/50
# 35/35 [==============================] - 7s 199ms/step - loss: 0.0892 - accuracy: 0.9737 - val_loss: 1.8861 - val_accuracy: 0.6571
# Epoch 8/50
# 35/35 [==============================] - 8s 220ms/step - loss: 0.0706 - accuracy: 0.9799 - val_loss: 1.2706 - val_accuracy: 0.6893
# Epoch 9/50
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0521 - accuracy: 0.9866 - val_loss: 2.4802 - val_accuracy: 0.4946
# Epoch 10/50
# 35/35 [==============================] - 7s 190ms/step - loss: 0.0525 - accuracy: 0.9835 - val_loss: 1.4333 - val_accuracy: 0.6714
# Epoch 11/50
# 35/35 [==============================] - 8s 230ms/step - loss: 0.0566 - accuracy: 0.9826 - val_loss: 1.6815 - val_accuracy: 0.6232
# Epoch 12/50
# 35/35 [==============================] - 7s 192ms/step - loss: 0.0384 - accuracy: 0.9897 - val_loss: 2.6259 - val_accuracy: 0.5179
# Epoch 13/50
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0456 - accuracy: 0.9879 - val_loss: 2.6951 - val_accuracy: 0.5143
# Epoch 14/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0483 - accuracy: 0.9839 - val_loss: 1.6052 - val_accuracy: 0.6893
# Epoch 15/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 2.8150 - val_accuracy: 0.4946
# Epoch 16/50
# 35/35 [==============================] - 6s 183ms/step - loss: 0.0279 - accuracy: 0.9933 - val_loss: 1.6688 - val_accuracy: 0.6893
# Epoch 17/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0889 - accuracy: 0.9701 - val_loss: 1.0879 - val_accuracy: 0.7571
# Epoch 18/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0650 - accuracy: 0.9808 - val_loss: 1.6013 - val_accuracy: 0.6071
# Epoch 19/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0317 - accuracy: 0.9897 - val_loss: 1.5531 - val_accuracy: 0.6964
# Epoch 20/50
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0490 - accuracy: 0.9875 - val_loss: 1.9853 - val_accuracy: 0.6643
# Epoch 21/50
# 35/35 [==============================] - 8s 238ms/step - loss: 0.0384 - accuracy: 0.9884 - val_loss: 2.4976 - val_accuracy: 0.4714
# Epoch 22/50
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0273 - accuracy: 0.9920 - val_loss: 1.8679 - val_accuracy: 0.6768
# Epoch 23/50
# 35/35 [==============================] - 9s 248ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 2.0171 - val_accuracy: 0.6482
# Epoch 24/50
# 35/35 [==============================] - 9s 245ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 1.6290 - val_accuracy: 0.6911
# Epoch 25/50
# 35/35 [==============================] - 7s 192ms/step - loss: 0.0315 - accuracy: 0.9915 - val_loss: 2.3138 - val_accuracy: 0.6286
# Epoch 26/50
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0498 - accuracy: 0.9835 - val_loss: 3.0392 - val_accuracy: 0.4214
# Epoch 27/50
# 35/35 [==============================] - 7s 191ms/step - loss: 0.0384 - accuracy: 0.9871 - val_loss: 1.3126 - val_accuracy: 0.7393
# Epoch 28/50
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 1.2299 - val_accuracy: 0.7607
# Epoch 29/50
# 35/35 [==============================] - 7s 190ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 1.8673 - val_accuracy: 0.6357
# Epoch 30/50
# 35/35 [==============================] - 7s 186ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 2.0947 - val_accuracy: 0.6375
# Epoch 31/50
# 35/35 [==============================] - 7s 188ms/step - loss: 0.0305 - accuracy: 0.9911 - val_loss: 3.4620 - val_accuracy: 0.4911
# Epoch 32/50
# 35/35 [==============================] - 6s 183ms/step - loss: 0.0601 - accuracy: 0.9817 - val_loss: 1.8562 - val_accuracy: 0.6429
# Epoch 33/50
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 2.5536 - val_accuracy: 0.5554
# Epoch 34/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 1.4138 - val_accuracy: 0.7107
# Epoch 35/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 2.4501 - val_accuracy: 0.5500
# Epoch 36/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0352 - accuracy: 0.9902 - val_loss: 2.1928 - val_accuracy: 0.6143
# Epoch 37/50
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0419 - accuracy: 0.9875 - val_loss: 2.9888 - val_accuracy: 0.5089
# Epoch 38/50
# 35/35 [==============================] - 7s 184ms/step - loss: 0.0099 - accuracy: 0.9955 - val_loss: 2.9584 - val_accuracy: 0.5393
# Epoch 39/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0112 - accuracy: 0.9969 - val_loss: 2.9782 - val_accuracy: 0.5393
# Epoch 40/50
# 35/35 [==============================] - 6s 183ms/step - loss: 0.0137 - accuracy: 0.9946 - val_loss: 2.2916 - val_accuracy: 0.6589
# Epoch 41/50
# 35/35 [==============================] - 6s 183ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 1.8354 - val_accuracy: 0.6893
# Epoch 42/50
# 35/35 [==============================] - 7s 193ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 2.3571 - val_accuracy: 0.6393
# Epoch 43/50
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.6310 - val_accuracy: 0.6107
# Epoch 44/50
# 35/35 [==============================] - 6s 181ms/step - loss: 8.4146e-04 - accuracy: 1.0000 - val_loss: 2.5061 - val_accuracy: 0.6268
# Epoch 45/50
# 35/35 [==============================] - 7s 195ms/step - loss: 6.6080e-04 - accuracy: 1.0000 - val_loss: 2.4822 - val_accuracy: 0.6304
# Epoch 46/50
# 35/35 [==============================] - 8s 232ms/step - loss: 4.8523e-04 - accuracy: 1.0000 - val_loss: 2.5645 - val_accuracy: 0.6286
# Epoch 47/50
# 35/35 [==============================] - 7s 185ms/step - loss: 2.9038e-04 - accuracy: 1.0000 - val_loss: 2.5547 - val_accuracy: 0.6321
# Epoch 48/50
# 35/35 [==============================] - 6s 185ms/step - loss: 2.5904e-04 - accuracy: 1.0000 - val_loss: 2.5717 - val_accuracy: 0.6321
# Epoch 49/50
# 35/35 [==============================] - 6s 184ms/step - loss: 4.3715e-04 - accuracy: 1.0000 - val_loss: 2.5108 - val_accuracy: 0.6482
# Epoch 50/50
# 35/35 [==============================] - 7s 188ms/step - loss: 4.4459e-04 - accuracy: 1.0000 - val_loss: 2.5825 - val_accuracy: 0.6375

# %%
# best val accuracy: 72.32
# use checkpoint to save the best val accuracy model
# adjust learning rate for slow convergence

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model.save('SER_model.h5')

# %%
from tensorflow.keras.models import load_model
SER_model = load_model('SER_model.h5')

# %%
SER_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import librosa
import numpy as np
from keras.models import load_model

# Load the model
model = load_model('model/SER_model.h5')  # Replace with the path to your model file

# Define the predict function
def predict_emotion(audio_file):
    # Extract MFCC features from the audio file
    mfcc = extract_mfcc(audio_file)  # Assuming you've defined this function

    # Reshape the MFCC features to match the model's input shape
    mfcc = mfcc.reshape(1, 40, 1)  # Shape should match (batch_size, num_features, num_timesteps)

    # Make predictions using the loaded model
    predictions = model.predict(mfcc)

    # Get the predicted emotion label
    predicted_label = np.argmax(predictions)

    if predicted_label==0:
        return 'Emotion: Angry'
    elif predicted_label==1:
        return 'Emotion: Disgust'
    elif predicted_label==2:
        return 'Emotion: Fear'
    elif predicted_label==3:
        return 'Emotion: Happy'
    elif predicted_label==4:
        return 'Emotion: Neutral'
    elif predicted_label==5:
        return 'Emotion: Pleasant_surprise'
    else:
        return 'Emotion: Sad'
    #return predicted_label  # Return the index of the predicted emotion category

# %%
pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in /usr/local/lib/python3.11/site-packages (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/site-packages (from sounddevice) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sounddevice as sd
from scipy.io import wavfile
from IPython.display import Audio

# %%
# Function to record audio and save it to a WAV file
def record_audio(file_path, duration=5):
    print("Recording audio...")
    audio_data = sd.rec(int(duration * 44100), samplerate=44100, channels=1, blocking=True)
    wavfile.write(file_path, 44100, audio_data)
    print(f"Audio saved to {file_path}")

# %%
# Record and save audio
record_audio(audio_file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Record and save audio
# ----> 2 record_audio(audio_file_path)
#
# NameError: name 'audio_file_path' is not defined

# %%
# Play the recorded audio
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#audio_file_path = ''# Replace with the path to your audio file
predicted_emotion_index = predict_emotion(audio_file_path)
print(predicted_emotion_index)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Emotion: Disgust

# %%
audio_file_path = 'TESS_Toronto_emotional_speech_set_data/OAF_angry/OAF_back_angry.wav'
predicted_emotion_index = predict_emotion(audio_file_path)
print(predicted_emotion_index)
# Out:
# 1/1 [==============================] - 0s 493ms/step
# Emotion: Disgust
